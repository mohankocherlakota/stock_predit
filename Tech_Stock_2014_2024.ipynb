# %%
import pandas as pd
import os

# List of file paths (replace with your actual paths)
file_paths = [
    'AAPL_2014_2024.csv',
    'ACN_2014_2024.csv',
    'ADBE_2014_2024.csv',
    'AMD_2014_2024.csv',
    'AVGO_2014_2024.csv',
    'CRM_2014_2024.csv',
    'CSCO_2014_2024.csv',
    'NVDA_2014_2024.csv',
    'ORCL_2014_2024.csv'
]

# Combine all CSVs into one DataFrame with an additional column
dataframes = []
for file in file_paths:
    # Extract the identifier from the file name
    identifier = os.path.basename(file).split('_')[0]
    # Read CSV and add a new column
    df = pd.read_csv(file)
    df['Source'] = identifier
    dataframes.append(df)

# Concatenate all DataFrames
combined_df = pd.concat(dataframes)

# Save the combined DataFrame to a new CSV file
combined_df.to_csv('combined_stocks_2014_2024.csv', index=False)

print("CSV files combined successfully into 'combined_2014_2024.csv' with a new 'Source' column")
# Out:
# CSV files combined successfully into 'combined_2014_2024.csv' with a new 'Source' column

# %%
import pandas as pd
import os
import numpy as np

# %%
df= pd.read_csv("combined_stocks_2014_2024.csv")
df
# Out:
#              Date        Open        High         Low       Close   Adj Close  \
# 0      2014-01-02   19.845715   19.893929   19.715000   19.754642   17.234303
# 1      2014-01-03   19.745001   19.775000   19.301071   19.320715   16.855726
# 2      2014-01-06   19.194643   19.528570   19.057142   19.426071   16.947647
# 3      2014-01-07   19.440001   19.498571   19.211430   19.287144   16.826445
# 4      2014-01-08   19.243214   19.484285   19.238930   19.409286   16.933004
# ...           ...         ...         ...         ...         ...         ...
# 24583  2024-11-01  170.149994  172.270004  169.100006  170.020004  170.020004
# 24584  2024-11-04  170.309998  170.479996  168.729996  169.589996  169.589996
# 24585  2024-11-05  170.470001  171.889999  170.320007  171.779999  171.779999
# 24586  2024-11-06  178.520004  182.100006  177.419998  181.240005  181.240005
# 24587  2024-11-07  181.080002  186.669998  180.539993  186.369995  186.369995
#
#           Volume Source
# ...

# %%
import pycaret
pycaret.__version__
# Out:
# '3.3.2'

# %%
from pycaret.regression import *

s = setup(df, target = 'Close')
# Out:
# <style type="text/css">
# #T_6044f_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6044f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6044f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6044f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6044f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6044f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6044f_row0_col1" class="data row0 col1" >2434</td>
#     </tr>
#     <tr>
#       <th id="T_6044f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6044f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6044f_row1_col1" class="data row1 col1" >Close</td>
#     </tr>
#     <tr>
#       <th id="T_6044f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_64cfb th {
#   text-align: left;
# }
# ...
